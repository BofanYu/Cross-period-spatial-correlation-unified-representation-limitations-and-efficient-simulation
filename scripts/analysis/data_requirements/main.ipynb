# %% [markdown]
# # 6.5 Data requirements â€” Figure 4
# Each selected event subset is refitted and its curves compared with the full-data reference. The fixed event and station selections are in `results/analysis/model_fit/samples/`.
#
# The recorded measurement table below is embedded explicitly so the figure remains available without rerunning thousands of fits. It is a saved experiment, not a fresh optimizer run. Counts show 100/97/100/94/100 available repetitions; the 134-event endpoints are reference values, with 98 LMC MLE fits.

# %%
from pathlib import Path
import sys
ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "scripts/models").is_dir())
sys.path.insert(0, str(ROOT))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Image
from threadpoolctl import threadpool_limits
from scripts.common import core
MODEL_DIR = ROOT / "results/analysis/model_fit"
FIGURES = ROOT / "results/figures"
FIGURES.mkdir(parents=True, exist_ok=True)
payload = core.load_pickle_cross_platform(MODEL_DIR / "models.pkl")

# %%
import io
recorded_summary = pd.read_csv(io.StringIO('display_name,model,n_events,n_success,rmse_median,rmse_mean,rmse_std\r\nGH08 semivariogram,gh08,40,100,0.02995,0.03061,0.01066\r\nGH08 semivariogram,gh08,60,97,0.02182,0.02256,0.00763\r\nGH08 semivariogram,gh08,80,100,0.01607,0.01711,0.0062\r\nGH08 semivariogram,gh08,100,94,0.01221,0.01252,0.00509\r\nGH08 semivariogram,gh08,120,100,0.00439,0.00548,0.00353\r\nGH08 semivariogram,gh08,134,1,0.0,0.0,0.0\r\nLMC MLE,lmc_block_mle,40,100,0.02215,0.02268,0.00752\r\nLMC MLE,lmc_block_mle,60,97,0.01656,0.01722,0.00628\r\nLMC MLE,lmc_block_mle,80,100,0.0126,0.01291,0.00419\r\nLMC MLE,lmc_block_mle,100,94,0.0095,0.0103,0.00349\r\nLMC MLE,lmc_block_mle,120,100,0.00683,0.00694,0.00246\r\nLMC MLE,lmc_block_mle,134,98,0.00357,0.00244,0.00212\r\nPCA MLE,pca_mle,40,100,0.02821,0.03236,0.01609\r\nPCA MLE,pca_mle,60,97,0.0196,0.02377,0.01379\r\nPCA MLE,pca_mle,80,100,0.01423,0.0167,0.00871\r\nPCA MLE,pca_mle,100,94,0.01143,0.01331,0.00817\r\nPCA MLE,pca_mle,120,100,0.00545,0.00706,0.00456\r\nPCA MLE,pca_mle,134,1,0.0,0.0,0.0\r\nPCA semivariogram,pca_semivariogram,40,100,0.04235,0.05315,0.03642\r\nPCA semivariogram,pca_semivariogram,60,97,0.03019,0.03512,0.0244\r\nPCA semivariogram,pca_semivariogram,80,100,0.02527,0.02751,0.01707\r\nPCA semivariogram,pca_semivariogram,100,94,0.01416,0.01977,0.01482\r\nPCA semivariogram,pca_semivariogram,120,100,0.00623,0.00846,0.00765\r\nPCA semivariogram,pca_semivariogram,134,1,0.0,0.0,0.0\r\nSeparable kernel semivariogram,kronecker,40,100,0.0206,0.02375,0.01274\r\nSeparable kernel semivariogram,kronecker,60,97,0.01618,0.01811,0.00911\r\nSeparable kernel semivariogram,kronecker,80,100,0.01291,0.01367,0.00658\r\nSeparable kernel semivariogram,kronecker,100,94,0.00935,0.01013,0.00547\r\nSeparable kernel semivariogram,kronecker,120,100,0.00319,0.00408,0.00328\r\nSeparable kernel semivariogram,kronecker,134,1,0.0,0.0,0.0\r\nPairwise empirical semivariogram,pairwise,40,100,0.0410223626522445,0.0431916701161714,0.0153808375926653\r\nPairwise empirical semivariogram,pairwise,60,97,0.0316892771792404,0.0329983723051224,0.0122523868294766\r\nPairwise empirical semivariogram,pairwise,80,100,0.0240379861410537,0.0254268433746601,0.0107758346921065\r\nPairwise empirical semivariogram,pairwise,100,94,0.0166977233243537,0.0185549590994557,0.0096776017398654\r\nPairwise empirical semivariogram,pairwise,120,100,0.0062438052151071,0.0082418738104535,0.0059785290617103\r\nPairwise empirical semivariogram,pairwise,134,1,0.0,0.0,0.0\r\nLMC semivariogram,lmc,40,100,0.0307153060218292,0.0323571265758394,0.0114344595948568\r\nLMC semivariogram,lmc,60,97,0.0205033750248102,0.0217177656533275,0.0077985242827195\r\nLMC semivariogram,lmc,80,100,0.0164124489344265,0.0164261009574118,0.005812436268988\r\nLMC semivariogram,lmc,100,94,0.0116782903396185,0.0119892156297958,0.0048849575750504\r\nLMC semivariogram,lmc,120,100,0.0049280320348071,0.0056698226670006,0.0033071471337536\r\nLMC semivariogram,lmc,134,1,0.0,0.0,0.0\r\n'))
display(recorded_summary)
# Out:
#                         display_name              model  n_events  n_success  \
# 0                 GH08 semivariogram               gh08        40        100
# 1                 GH08 semivariogram               gh08        60         97
# 2                 GH08 semivariogram               gh08        80        100
# 3                 GH08 semivariogram               gh08       100         94
# 4                 GH08 semivariogram               gh08       120        100
# 5                 GH08 semivariogram               gh08       134          1
# 6                            LMC MLE      lmc_block_mle        40        100
# 7                            LMC MLE      lmc_block_mle        60         97
# 8                            LMC MLE      lmc_block_mle        80        100
# 9                            LMC MLE      lmc_block_mle       100         94
# 10                           LMC MLE      lmc_block_mle       120        100
# 11                           LMC MLE      lmc_block_mle       134         98
# 12                           PCA MLE            pca_mle        40        100
# 13                           PCA MLE            pca_mle        60         97
# 14                           PCA MLE            pca_mle        80        100
# 15                           PCA MLE            pca_mle       100         94
# 16                           PCA MLE            pca_mle       120        100
# 17                           PCA MLE            pca_mle       134          1
# 18                 PCA semivariogram  pca_semivariogram        40        100
# 19                 PCA semivariogram  pca_semivariogram        60         97
# 20                 PCA semivariogram  pca_semivariogram        80        100
# 21                 PCA semivariogram  pca_semivariogram       100         94
# 22                 PCA semivariogram  pca_semivariogram       120        100
# 23                 PCA semivariogram  pca_semivariogram       134          1
# 24    Separable kernel semivariogram          kronecker        40        100
# 25    Separable kernel semivariogram          kronecker        60         97
# 26    Separable kernel semivariogram          kronecker        80        100
# 27    Separable kernel semivariogram          kronecker       100         94
# 28    Separable kernel semivariogram          kronecker       120        100
# 29    Separable kernel semivariogram          kronecker       134          1
# 30  Pairwise empirical semivariogram           pairwise        40        100
# 31  Pairwise empirical semivariogram           pairwise        60         97
# 32  Pairwise empirical semivariogram           pairwise        80        100
# 33  Pairwise empirical semivariogram           pairwise       100         94
# 34  Pairwise empirical semivariogram           pairwise       120        100
# 35  Pairwise empirical semivariogram           pairwise       134          1
# 36                 LMC semivariogram                lmc        40        100
# 37                 LMC semivariogram                lmc        60         97
# 38                 LMC semivariogram                lmc        80        100
# 39                 LMC semivariogram                lmc       100         94
# 40                 LMC semivariogram                lmc       120        100
# 41                 LMC semivariogram                lmc       134          1
#
#     rmse_median  rmse_mean  rmse_std
# 0      0.029950   0.030610  0.010660
# 1      0.021820   0.022560  0.007630
# 2      0.016070   0.017110  0.006200
# 3      0.012210   0.012520  0.005090
# 4      0.004390   0.005480  0.003530
# 5      0.000000   0.000000  0.000000
# 6      0.022150   0.022680  0.007520
# 7      0.016560   0.017220  0.006280
# 8      0.012600   0.012910  0.004190
# 9      0.009500   0.010300  0.003490
# 10     0.006830   0.006940  0.002460
# 11     0.003570   0.002440  0.002120
# 12     0.028210   0.032360  0.016090
# 13     0.019600   0.023770  0.013790
# 14     0.014230   0.016700  0.008710
# 15     0.011430   0.013310  0.008170
# 16     0.005450   0.007060  0.004560
# 17     0.000000   0.000000  0.000000
# 18     0.042350   0.053150  0.036420
# 19     0.030190   0.035120  0.024400
# 20     0.025270   0.027510  0.017070
# 21     0.014160   0.019770  0.014820
# 22     0.006230   0.008460  0.007650
# 23     0.000000   0.000000  0.000000
# 24     0.020600   0.023750  0.012740
# 25     0.016180   0.018110  0.009110
# 26     0.012910   0.013670  0.006580
# 27     0.009350   0.010130  0.005470
# 28     0.003190   0.004080  0.003280
# 29     0.000000   0.000000  0.000000
# 30     0.041022   0.043192  0.015381
# 31     0.031689   0.032998  0.012252
# 32     0.024038   0.025427  0.010776
# 33     0.016698   0.018555  0.009678
# 34     0.006244   0.008242  0.005979
# 35     0.000000   0.000000  0.000000
# 36     0.030715   0.032357  0.011434
# 37     0.020503   0.021718  0.007799
# 38     0.016412   0.016426  0.005812
# 39     0.011678   0.011989  0.004885
# 40     0.004928   0.005670  0.003307
# 41     0.000000   0.000000  0.000000

# %% [markdown]
# ## Rerun the experiment
# Set `RERUN=True` for a selected 40-event example. Use event_grid=(40,60,80,100,120,134), max_reps=None for the full saved sample schedule. LMC MLE makes the main and supplementary runs expensive; `models="baseline"` runs the six faster main variants.

# %%
from scripts.analysis.data_requirements.experiment import run_experiment
RERUN = False
if RERUN:
    with threadpool_limits(limits=1):
        detail, rerun_summary = run_experiment(models='main', event_grid=(40,), max_reps=1)
    display(detail)
    display(rerun_summary)

# %% [markdown]
# ## Draw the figure
# With `RERUN=True`, this cell draws the new results. Otherwise it draws the recorded full experiment. A single repetition has no sample standard deviation; use at least two repetitions for that panel.

# %%
from scripts.analysis.data_requirements.figures import data_requirements
from scripts.common.styles import ALL_MODELS
summary = rerun_summary.copy() if RERUN else recorded_summary.copy()
summary["display_name"] = summary.display_name.replace({"Kronecker semivariogram": "Separable kernel semivariogram"})
methods = list(ALL_MODELS[:7])
display(summary.loc[summary.display_name.isin(methods), ["display_name", "n_events", "n_success", "rmse_median", "rmse_std"]])
fig = data_requirements(summary, methods, True)
fig.savefig(FIGURES / 'fig04_data_requirements.png', dpi=240, bbox_inches="tight", pad_inches=.04)
display(Image(filename=str(FIGURES / 'fig04_data_requirements.png')))
plt.close(fig)
# Out:
#                         display_name  n_events  n_success  rmse_median  \
# 0                 GH08 semivariogram        40        100     0.029950
# 1                 GH08 semivariogram        60         97     0.021820
# 2                 GH08 semivariogram        80        100     0.016070
# 3                 GH08 semivariogram       100         94     0.012210
# 4                 GH08 semivariogram       120        100     0.004390
# 5                 GH08 semivariogram       134          1     0.000000
# 6                            LMC MLE        40        100     0.022150
# 7                            LMC MLE        60         97     0.016560
# 8                            LMC MLE        80        100     0.012600
# 9                            LMC MLE       100         94     0.009500
# 10                           LMC MLE       120        100     0.006830
# 11                           LMC MLE       134         98     0.003570
# 12                           PCA MLE        40        100     0.028210
# 13                           PCA MLE        60         97     0.019600
# 14                           PCA MLE        80        100     0.014230
# 15                           PCA MLE       100         94     0.011430
# 16                           PCA MLE       120        100     0.005450
# 17                           PCA MLE       134          1     0.000000
# 18                 PCA semivariogram        40        100     0.042350
# 19                 PCA semivariogram        60         97     0.030190
# 20                 PCA semivariogram        80        100     0.025270
# 21                 PCA semivariogram       100         94     0.014160
# 22                 PCA semivariogram       120        100     0.006230
# 23                 PCA semivariogram       134          1     0.000000
# 24    Separable kernel semivariogram        40        100     0.020600
# 25    Separable kernel semivariogram        60         97     0.016180
# 26    Separable kernel semivariogram        80        100     0.012910
# 27    Separable kernel semivariogram       100         94     0.009350
# 28    Separable kernel semivariogram       120        100     0.003190
# 29    Separable kernel semivariogram       134          1     0.000000
# 30  Pairwise empirical semivariogram        40        100     0.041022
# 31  Pairwise empirical semivariogram        60         97     0.031689
# 32  Pairwise empirical semivariogram        80        100     0.024038
# 33  Pairwise empirical semivariogram       100         94     0.016698
# 34  Pairwise empirical semivariogram       120        100     0.006244
# 35  Pairwise empirical semivariogram       134          1     0.000000
# 36                 LMC semivariogram        40        100     0.030715
# 37                 LMC semivariogram        60         97     0.020503
# 38                 LMC semivariogram        80        100     0.016412
# 39                 LMC semivariogram       100         94     0.011678
# 40                 LMC semivariogram       120        100     0.004928
# 41                 LMC semivariogram       134          1     0.000000
#
#     rmse_std
# 0   0.010660
# 1   0.007630
# 2   0.006200
# 3   0.005090
# 4   0.003530
# 5   0.000000
# 6   0.007520
# 7   0.006280
# 8   0.004190
# 9   0.003490
# 10  0.002460
# 11  0.002120
# 12  0.016090
# 13  0.013790
# 14  0.008710
# 15  0.008170
# 16  0.004560
# 17  0.000000
# 18  0.036420
# 19  0.024400
# 20  0.017070
# 21  0.014820
# 22  0.007650
# 23  0.000000
# 24  0.012740
# 25  0.009110
# 26  0.006580
# 27  0.005470
# 28  0.003280
# 29  0.000000
# 30  0.015381
# 31  0.012252
# 32  0.010776
# 33  0.009678
# 34  0.005979
# 35  0.000000
# 36  0.011434
# 37  0.007799
# 38  0.005812
# 39  0.004885
# 40  0.003307
# 41  0.000000
